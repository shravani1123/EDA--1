# %% [markdown]
# # **Importing libraries**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **Loading DataSet**

# %%
df = pd.read_csv('/content/data.csv', encoding = 'ISO-8859-1')

# %%
# ecom_data = pd.read_csv('data.csv', encoding = 'ISO-8859-1')

# %% [markdown]
# # **Number of rows and columns**

# %%
df.shape
# Out:
# (541909, 8)

# %% [markdown]
# # **Acessing first five rows**

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# # **Acessing last five rows**

# %%
df.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country
# 541904  12/9/2011 12:50       0.85     12680.0  France
# 541905  12/9/2011 12:50       2.10     12680.0  France
# 541906  12/9/2011 12:50       4.15     12680.0  France
# 541907  12/9/2011 12:50       4.15     12680.0  France
# 541908  12/9/2011 12:50       4.95     12680.0  France

# %% [markdown]
# # **Displaying total columns from DataSet**

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %% [markdown]
# # **Getting all columns one by one**

# %%
for col in df.columns:
    print(col)
# Out:
# InvoiceNo
# StockCode
# Description
# Quantity
# InvoiceDate
# UnitPrice
# CustomerID
# Country

# %% [markdown]
# # **Renaming columns names**

# %%
d = {
        'InvoiceNo' : 'invoice_num',
        'StockCode' : 'stock_code',
        'Description' : 'description',
        'Quantity' : 'quantity',
        'InvoiceDate' : 'invoice_date',
        'UnitPrice' : 'unit_price',
        'CustomerID' : 'cust_id',
        'Country' : 'country',
}

# %%
df.rename(columns = d, inplace= True)

# %% [markdown]
# # **Revisiting new column names**

# %%
df.columns
# Out:
# Index(['invoice_num', 'stock_code', 'description', 'quantity', 'invoice_date',
#        'unit_price', 'cust_id', 'country'],
#       dtype='object')

# %%
for i in df.columns:
    print(i)
# Out:
# invoice_num
# stock_code
# description
# quantity
# invoice_date
# unit_price
# cust_id
# country

# %% [markdown]
# # **Lets check initial data**

# %%
df.head()
# Out:
#   invoice_num stock_code                          description  quantity  \
# 0      536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      536365      71053                  WHITE METAL LANTERN         6
# 2      536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3      536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#      invoice_date  unit_price  cust_id         country
# 0  12/1/2010 8:26        2.55  17850.0  United Kingdom
# 1  12/1/2010 8:26        3.39  17850.0  United Kingdom
# 2  12/1/2010 8:26        2.75  17850.0  United Kingdom
# 3  12/1/2010 8:26        3.39  17850.0  United Kingdom
# 4  12/1/2010 8:26        3.39  17850.0  United Kingdom

# %% [markdown]
# # **DATA CLEANING**

# %% [markdown]
# # **Checking column types**

# %%
df.dtypes
# Out:
# invoice_num      object
# stock_code       object
# description      object
# quantity          int64
# invoice_date     object
# unit_price      float64
# cust_id         float64
# country          object
# dtype: object

# %% [markdown]
# # **DataFrame Information**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice_num   541909 non-null  object
#  1   stock_code    541909 non-null  object
#  2   description   540455 non-null  object
#  3   quantity      541909 non-null  int64
#  4   invoice_date  541909 non-null  object
#  5   unit_price    541909 non-null  float64
#  6   cust_id       406829 non-null  float64
#  7   country       541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %% [markdown]
# # **Checking missing values**

# %%
df.isnull()
# Out:
#         invoice_num  stock_code  description  quantity  invoice_date  \
# 0             False       False        False     False         False
# 1             False       False        False     False         False
# 2             False       False        False     False         False
# 3             False       False        False     False         False
# 4             False       False        False     False         False
# ...             ...         ...          ...       ...           ...
# 541904        False       False        False     False         False
# 541905        False       False        False     False         False
# 541906        False       False        False     False         False
# 541907        False       False        False     False         False
# 541908        False       False        False     False         False
#
#         unit_price  cust_id  country
# 0            False    False    False
# 1            False    False    False
# ...

# %% [markdown]
# # **Checking number of columns**

# %%
len(df.columns)
# Out:
# 8

# %%
df.shape
# Out:
# (541909, 8)

# %% [markdown]
# # **Checking missing values count on each column**

# %%
df.isnull().sum()
# Out:
# invoice_num          0
# stock_code           0
# description       1454
# quantity             0
# invoice_date         0
# unit_price           0
# cust_id         135080
# country              0
# dtype: int64

# %% [markdown]
# # **Checking missing values on each column : Applying sorting**

# %%
df.isnull().sum().sort_values()
# Out:
# invoice_num          0
# stock_code           0
# quantity             0
# invoice_date         0
# unit_price           0
# country              0
# description       1454
# cust_id         135080
# dtype: int64

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# cust_id         135080
# description       1454
# invoice_num          0
# stock_code           0
# quantity             0
# invoice_date         0
# unit_price           0
# country              0
# dtype: int64

# %% [markdown]
# # **Checking type of invoice_date column**

# %%
df.dtypes
# Out:
# invoice_num      object
# stock_code       object
# description      object
# quantity          int64
# invoice_date     object
# unit_price      float64
# cust_id         float64
# country          object
# dtype: object

# %% [markdown]
# # **Access initial data**

# %%
df.head(2)
# Out:
#   invoice_num stock_code                         description  quantity  \
# 0      536365     85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      536365      71053                 WHITE METAL LANTERN         6
#
#      invoice_date  unit_price  cust_id         country
# 0  12/1/2010 8:26        2.55  17850.0  United Kingdom
# 1  12/1/2010 8:26        3.39  17850.0  United Kingdom

# %% [markdown]
# # **Converting invoice_date data type into datatime**

# %%
df['invoice_date'] = pd.to_datetime(df.invoice_date, format='%m/%d/%Y %H:%M')

# %% [markdown]
# # **Re-checking type of invoice_date**

# %%
 df.dtypes
# Out:
# invoice_num             object
# stock_code              object
# description             object
# quantity                 int64
# invoice_date    datetime64[ns]
# unit_price             float64
# cust_id                float64
# country                 object
# dtype: object

# %%
df.head(3)
# Out:
#   invoice_num stock_code                         description  quantity  \
# 0      536365     85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      536365      71053                 WHITE METAL LANTERN         6
# 2      536365     84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#          invoice_date  unit_price  cust_id         country
# 0 2010-12-01 08:26:00        2.55  17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39  17850.0  United Kingdom
# 2 2010-12-01 08:26:00        2.75  17850.0  United Kingdom

# %% [markdown]
# # **Description Column**

# %%
df.description
# Out:
# 0          WHITE HANGING HEART T-LIGHT HOLDER
# 1                         WHITE METAL LANTERN
# 2              CREAM CUPID HEARTS COAT HANGER
# 3         KNITTED UNION FLAG HOT WATER BOTTLE
# 4              RED WOOLLY HOTTIE WHITE HEART.
#                          ...
# 541904            PACK OF 20 SPACEBOY NAPKINS
# 541905           CHILDREN'S APRON DOLLY GIRL
# 541906          CHILDRENS CUTLERY DOLLY GIRL
# 541907        CHILDRENS CUTLERY CIRCUS PARADE
# 541908          BAKING SET 9 PIECE RETROSPOT
# Name: description, Length: 541909, dtype: object

# %% [markdown]
# # **Calling lower() method**

# %%
df.description.str.lower()
# Out:
# 0          white hanging heart t-light holder
# 1                         white metal lantern
# 2              cream cupid hearts coat hanger
# 3         knitted union flag hot water bottle
# 4              red woolly hottie white heart.
#                          ...
# 541904            pack of 20 spaceboy napkins
# 541905           children's apron dolly girl
# 541906          childrens cutlery dolly girl
# 541907        childrens cutlery circus parade
# 541908          baking set 9 piece retrospot
# Name: description, Length: 541909, dtype: object

# %%
df['description'] = df.description.str.lower()

# %%
df.head(2)
# Out:
#   invoice_num stock_code                         description  quantity  \
# 0      536365     85123A  white hanging heart t-light holder         6
# 1      536365      71053                 white metal lantern         6
#
#          invoice_date  unit_price  cust_id         country
# 0 2010-12-01 08:26:00        2.55  17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39  17850.0  United Kingdom

# %% [markdown]
# # **MISSING VALUES**

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# cust_id         135080
# description       1454
# invoice_num          0
# stock_code           0
# quantity             0
# invoice_date         0
# unit_price           0
# country              0
# dtype: int64

# %% [markdown]
# # **Dropping missing values assinging to new variable**

# %%
df_new = df.dropna()

# %%
df_new.shape
# Out:
# (406829, 8)

# %%
df.shape
# Out:
# (541909, 8)

# %% [markdown]
# # **After dropping missing values checking them in each column**

# %%
df_new.isnull().sum()
# Out:
# invoice_num     0
# stock_code      0
# description     0
# quantity        0
# invoice_date    0
# unit_price      0
# cust_id         0
# country         0
# dtype: int64

# %% [markdown]
# # **DataFrame Information**

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice_num   406829 non-null  object
#  1   stock_code    406829 non-null  object
#  2   description   406829 non-null  object
#  3   quantity      406829 non-null  int64
#  4   invoice_date  406829 non-null  datetime64[ns]
#  5   unit_price    406829 non-null  float64
#  6   cust_id       406829 non-null  float64
#  7   country       406829 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 27.9+ MB

# %%
df_new.head()
# Out:
#   invoice_num stock_code                          description  quantity  \
# 0      536365     85123A   white hanging heart t-light holder         6
# 1      536365      71053                  white metal lantern         6
# 2      536365     84406B       cream cupid hearts coat hanger         8
# 3      536365     84029G  knitted union flag hot water bottle         6
# 4      536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  cust_id         country
# 0 2010-12-01 08:26:00        2.55  17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39  17850.0  United Kingdom
# 2 2010-12-01 08:26:00        2.75  17850.0  United Kingdom
# 3 2010-12-01 08:26:00        3.39  17850.0  United Kingdom
# 4 2010-12-01 08:26:00        3.39  17850.0  United Kingdom

# %% [markdown]
# # **Check type of cust_id data type**

# %%
df_new.dtypes
# Out:
# invoice_num             object
# stock_code              object
# description             object
# quantity                 int64
# invoice_date    datetime64[ns]
# unit_price             float64
# cust_id                float64
# country                 object
# dtype: object

# %% [markdown]
# # **Converting cust_id float type into integer type**

# %%
df_new['cust_id']
# Out:
# 0         17850.0
# 1         17850.0
# 2         17850.0
# 3         17850.0
# 4         17850.0
#            ...
# 541904    12680.0
# 541905    12680.0
# 541906    12680.0
# 541907    12680.0
# 541908    12680.0
# Name: cust_id, Length: 406829, dtype: float64

# %% [markdown]
# # **Ignoring warning**

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df_new['cust_id']=df_new['cust_id'].astype('int64')

# %% [markdown]
# # **Acessing first five rows**

# %%
df_new.head(2)
# Out:
#   invoice_num stock_code                         description  quantity  \
# 0      536365     85123A  white hanging heart t-light holder         6
# 1      536365      71053                 white metal lantern         6
#
#          invoice_date  unit_price  cust_id         country
# 0 2010-12-01 08:26:00        2.55    17850  United Kingdom
# 1 2010-12-01 08:26:00        3.39    17850  United Kingdom

# %% [markdown]
# # **New DataFrame Information**

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice_num   406829 non-null  object
#  1   stock_code    406829 non-null  object
#  2   description   406829 non-null  object
#  3   quantity      406829 non-null  int64
#  4   invoice_date  406829 non-null  datetime64[ns]
#  5   unit_price    406829 non-null  float64
#  6   cust_id       406829 non-null  int64
#  7   country       406829 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(4)
# memory usage: 27.9+ MB

# %% [markdown]
# # **DataFrame Description**

# %%
df_new.describe()
# Out:
#             quantity                   invoice_date     unit_price  \
# count  406829.000000                         406829  406829.000000
# mean       12.061303  2011-07-10 16:30:57.879207424       3.460471
# min    -80995.000000            2010-12-01 08:26:00       0.000000
# 25%         2.000000            2011-04-06 15:02:00       1.250000
# 50%         5.000000            2011-07-31 11:48:00       1.950000
# 75%        12.000000            2011-10-20 13:06:00       3.750000
# max     80995.000000            2011-12-09 12:50:00   38970.000000
# std       248.693370                            NaN      69.315162
#
#              cust_id
# count  406829.000000
# mean    15287.690570
# min     12346.000000
# 25%     13953.000000
# 50%     15152.000000
# 75%     16791.000000
# max     18287.000000
# std      1713.600303

# %% [markdown]
# # **Rounding the values in DataFrame**

# %%
df_new.describe().round(2)
# Out:
#         quantity                   invoice_date  unit_price    cust_id
# count  406829.00                         406829   406829.00  406829.00
# mean       12.06  2011-07-10 16:30:57.879207424        3.46   15287.69
# min    -80995.00            2010-12-01 08:26:00        0.00   12346.00
# 25%         2.00            2011-04-06 15:02:00        1.25   13953.00
# 50%         5.00            2011-07-31 11:48:00        1.95   15152.00
# 75%        12.00            2011-10-20 13:06:00        3.75   16791.00
# max     80995.00            2011-12-09 12:50:00    38970.00   18287.00
# std       248.69                            NaN       69.32    1713.60

# %% [markdown]
# # **Quantity column having negative values**

# %% [markdown]
# # **Filtering quantity column from neagtive values**

# %%
df_new.quantity > 0
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 541904    True
# 541905    True
# 541906    True
# 541907    True
# 541908    True
# Name: quantity, Length: 406829, dtype: bool

# %%
con = df_new.quantity > 0

# %%
df_new = df_new[con]

# %%
df_new.describe().round(2)
# Out:
#         quantity                   invoice_date  unit_price    cust_id
# count  397924.00                         397924   397924.00  397924.00
# mean       13.02  2011-07-10 23:43:36.912475648        3.12   15294.32
# min         1.00            2010-12-01 08:26:00        0.00   12346.00
# 25%         2.00            2011-04-07 11:12:00        1.25   13969.00
# 50%         6.00            2011-07-31 14:39:00        1.95   15159.00
# 75%        12.00            2011-10-20 14:33:00        3.75   16795.00
# max     80995.00            2011-12-09 12:50:00     8142.75   18287.00
# std       180.42                            NaN       22.10    1713.17

# %% [markdown]
# # **Access initial data**

# %%
df_new.head()
# Out:
#   invoice_num stock_code                          description  quantity  \
# 0      536365     85123A   white hanging heart t-light holder         6
# 1      536365      71053                  white metal lantern         6
# 2      536365     84406B       cream cupid hearts coat hanger         8
# 3      536365     84029G  knitted union flag hot water bottle         6
# 4      536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  cust_id         country
# 0 2010-12-01 08:26:00        2.55    17850  United Kingdom
# 1 2010-12-01 08:26:00        3.39    17850  United Kingdom
# 2 2010-12-01 08:26:00        2.75    17850  United Kingdom
# 3 2010-12-01 08:26:00        3.39    17850  United Kingdom
# 4 2010-12-01 08:26:00        3.39    17850  United Kingdom

# %% [markdown]
# # **Checking total number of rows and columns**

# %%
df_new.shape
# Out:
# (397924, 8)

# %%
df.shape
# Out:
# (541909, 8)

# %%
df_new.head()
# Out:
#   invoice_num stock_code                          description  quantity  \
# 0      536365     85123A   white hanging heart t-light holder         6
# 1      536365      71053                  white metal lantern         6
# 2      536365     84406B       cream cupid hearts coat hanger         8
# 3      536365     84029G  knitted union flag hot water bottle         6
# 4      536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  cust_id         country
# 0 2010-12-01 08:26:00        2.55    17850  United Kingdom
# 1 2010-12-01 08:26:00        3.39    17850  United Kingdom
# 2 2010-12-01 08:26:00        2.75    17850  United Kingdom
# 3 2010-12-01 08:26:00        3.39    17850  United Kingdom
# 4 2010-12-01 08:26:00        3.39    17850  United Kingdom

# %% [markdown]
# # **Adding the column - amount spent**

# %%
df_new['amount_spent'] = df_new['quantity'] * df_new['unit_price']

# %%
df_new.head(3)
# Out:
#   invoice_num stock_code                         description  quantity  \
# 0      536365     85123A  white hanging heart t-light holder         6
# 1      536365      71053                 white metal lantern         6
# 2      536365     84406B      cream cupid hearts coat hanger         8
#
#          invoice_date  unit_price  cust_id         country  amount_spent
# 0 2010-12-01 08:26:00        2.55    17850  United Kingdom         15.30
# 1 2010-12-01 08:26:00        3.39    17850  United Kingdom         20.34
# 2 2010-12-01 08:26:00        2.75    17850  United Kingdom         22.00

# %% [markdown]
# # **Checking amount_spent busniess**

# %%
df_new.amount_spent.sum()
# Out:
# 8911407.904

# %% [markdown]
# # **Re-checking column names from DataFrame**

# %%
for col in df_new.columns:
  print(col)
# Out:
# invoice_num
# stock_code
# description
# quantity
# invoice_date
# unit_price
# cust_id
# country
# amount_spent

# %% [markdown]
# # **Re-arranging columns for more readability**

# %%
col_order = ['invoice_num', 'invoice_date', 'stock_code', 'description', 'quantity', 'unit_price', 'amount_spent', 'cust_id', 'country']

# %%
df_new = df_new[col_order]

# %% [markdown]
# # **Access Initial data**

# %%
df_new.head(3)
# Out:
#   invoice_num        invoice_date stock_code  \
# 0      536365 2010-12-01 08:26:00     85123A
# 1      536365 2010-12-01 08:26:00      71053
# 2      536365 2010-12-01 08:26:00     84406B
#
#                           description  quantity  unit_price  amount_spent  \
# 0  white hanging heart t-light holder         6        2.55         15.30
# 1                 white metal lantern         6        3.39         20.34
# 2      cream cupid hearts coat hanger         8        2.75         22.00
#
#    cust_id         country
# 0    17850  United Kingdom
# 1    17850  United Kingdom
# 2    17850  United Kingdom

# %% [markdown]
# # **Number of rows and columns**

# %%
df_new.shape
# Out:
# (397924, 9)

# %% [markdown]
# # **Analysis on invoice_data column**

# %% [markdown]
# # **number of columns in the dataset**

# %%
len(df_new.columns)
# Out:
# 9

# %% [markdown]
# # **Accessing invoice_date column**

# %% [markdown]
# # **Method - 1 to access column**

# %%
df_new['invoice_date']
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: invoice_date, Length: 397924, dtype: datetime64[ns]

# %% [markdown]
# # **Method - 2 to access column**

# %%
df_new.invoice_date
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: invoice_date, Length: 397924, dtype: datetime64[ns]

# %% [markdown]
# # **Accessing year value from invoice_date**

# %%
df_new['invoice_date'].dt.year
# Out:
# 0         2010
# 1         2010
# 2         2010
# 3         2010
# 4         2010
#           ...
# 541904    2011
# 541905    2011
# 541906    2011
# 541907    2011
# 541908    2011
# Name: invoice_date, Length: 397924, dtype: int32

# %% [markdown]
# # **Accessing month value from invoice_date**

# %%
df_new['invoice_date'].dt.month
# Out:
# 0         12
# 1         12
# 2         12
# 3         12
# 4         12
#           ..
# 541904    12
# 541905    12
# 541906    12
# 541907    12
# 541908    12
# Name: invoice_date, Length: 397924, dtype: int32

# %%
df_new.head(2)
# Out:
#   invoice_num        invoice_date stock_code  \
# 0      536365 2010-12-01 08:26:00     85123A
# 1      536365 2010-12-01 08:26:00      71053
#
#                           description  quantity  unit_price  amount_spent  \
# 0  white hanging heart t-light holder         6        2.55         15.30
# 1                 white metal lantern         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# 1    17850  United Kingdom

# %% [markdown]
# # **SMALL CALCULATION**

# %%
y = 2010
m = 12

# %%
y_m = 100*2010 + 12

# %%
y_m
# Out:
# 201012

# %%
c1 = 'year_month'

# %%
v1 = df_new['invoice_date'].map(lambda col: 100 * col.year + col.month)

# %%
df_new.insert(loc = 2, column = c1, value = v1)

# %%
df_new
# Out:
#        invoice_num        invoice_date  year_month stock_code  \
# 0           536365 2010-12-01 08:26:00      201012     85123A
# 1           536365 2010-12-01 08:26:00      201012      71053
# 2           536365 2010-12-01 08:26:00      201012     84406B
# 3           536365 2010-12-01 08:26:00      201012     84029G
# 4           536365 2010-12-01 08:26:00      201012     84029E
# ...            ...                 ...         ...        ...
# 541904      581587 2011-12-09 12:50:00      201112      22613
# 541905      581587 2011-12-09 12:50:00      201112      22899
# 541906      581587 2011-12-09 12:50:00      201112      23254
# 541907      581587 2011-12-09 12:50:00      201112      23255
# 541908      581587 2011-12-09 12:50:00      201112      22138
#
#                                 description  quantity  unit_price  \
# 0        white hanging heart t-light holder         6        2.55
# 1                       white metal lantern         6        3.39
# ...

# %% [markdown]
# # **Adding month column to existing DataFrame**

# %%
c2 = 'month'

# %%
v2 = df_new.invoice_date.dt.month

# %%
df_new.insert(loc =3, column = c2, value = v2)

# %%
df_new.head(2)
# Out:
#   invoice_num        invoice_date  year_month  month stock_code  \
# 0      536365 2010-12-01 08:26:00      201012     12     85123A
# 1      536365 2010-12-01 08:26:00      201012     12      71053
#
#                           description  quantity  unit_price  amount_spent  \
# 0  white hanging heart t-light holder         6        2.55         15.30
# 1                 white metal lantern         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# 1    17850  United Kingdom

# %%
df_new.shape
# Out:
# (397924, 11)

# %% [markdown]
# # **Lets access invoice_date column**

# %%
df_new.invoice_date
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: invoice_date, Length: 397924, dtype: datetime64[ns]

# %% [markdown]
# # **We can get day of the week**

# %%
df_new['day_of_week'] = df_new['invoice_date'].dt.dayofweek

# %% [markdown]
# # **date format starts from 0**

# %% [markdown]
# # **Applying + 1 to make monday =1...until sunday =7**

# %%
c3 = 'day'

# %%
v3 = (df_new.invoice_date.dt.dayofweek)+1

# %%
df_new.insert(loc = 4, column = c3, value = v3)

# %%
df_new.head(2)
# Out:
#   invoice_num        invoice_date  year_month  month  day stock_code  \
# 0      536365 2010-12-01 08:26:00      201012     12    3     85123A
# 1      536365 2010-12-01 08:26:00      201012     12    3      71053
#
#                           description  quantity  unit_price  amount_spent  \
# 0  white hanging heart t-light holder         6        2.55         15.30
# 1                 white metal lantern         6        3.39         20.34
#
#    cust_id         country  day_of_week
# 0    17850  United Kingdom            2
# 1    17850  United Kingdom            2

# %% [markdown]
# # **Adding hour column to existing DataFrame**

# %%
df_new.invoice_date
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: invoice_date, Length: 397924, dtype: datetime64[ns]

# %%
#dir(df_new.invoice_date)

# %%
#dir(df_new.invoice_date.dt)

# %%
#dir df_new.invoice_date.dt.hour

# %%
c4 = "hour"

# %%
v4 = df_new.invoice_date.dt.hour

# %%
df_new.insert(loc = 5, column = c4, value = v4)

# %%
df_new.head(2)
# Out:
#   invoice_num        invoice_date  year_month  month  day  hour stock_code  \
# 0      536365 2010-12-01 08:26:00      201012     12    3     8     85123A
# 1      536365 2010-12-01 08:26:00      201012     12    3     8      71053
#
#                           description  quantity  unit_price  amount_spent  \
# 0  white hanging heart t-light holder         6        2.55         15.30
# 1                 white metal lantern         6        3.39         20.34
#
#    cust_id         country  day_of_week
# 0    17850  United Kingdom            2
# 1    17850  United Kingdom            2

# %% [markdown]
# # **Lets display all columns**

# %%
df_new.columns
# Out:
# Index(['invoice_num', 'invoice_date', 'year_month', 'month', 'day', 'hour',
#        'stock_code', 'description', 'quantity', 'unit_price', 'amount_spent',
#        'cust_id', 'country', 'day_of_week'],
#       dtype='object')

# %%
for col in df_new.columns:
  print(col)
# Out:
# invoice_num
# invoice_date
# year_month
# month
# day
# hour
# stock_code
# description
# quantity
# unit_price
# amount_spent
# cust_id
# country
# day_of_week

# %% [markdown]
# # **Exploratory Data Analysis (EDA)**

# %%
df_new.head(3)
# Out:
#   invoice_num        invoice_date  year_month  month  day  hour stock_code  \
# 0      536365 2010-12-01 08:26:00      201012     12    3     8     85123A
# 1      536365 2010-12-01 08:26:00      201012     12    3     8      71053
# 2      536365 2010-12-01 08:26:00      201012     12    3     8     84406B
#
#                           description  quantity  unit_price  amount_spent  \
# 0  white hanging heart t-light holder         6        2.55         15.30
# 1                 white metal lantern         6        3.39         20.34
# 2      cream cupid hearts coat hanger         8        2.75         22.00
#
#    cust_id         country  day_of_week
# 0    17850  United Kingdom            2
# 1    17850  United Kingdom            2
# 2    17850  United Kingdom            2

# %%
df_new.groupby(by =  ['cust_id']). count()
# Out:
#          invoice_num  invoice_date  year_month  month  day  hour  stock_code  \
# cust_id
# 12346              1             1           1      1    1     1           1
# 12347            182           182         182    182  182   182         182
# 12348             31            31          31     31   31    31          31
# 12349             73            73          73     73   73    73          73
# 12350             17            17          17     17   17    17          17
# ...              ...           ...         ...    ...  ...   ...         ...
# 18280             10            10          10     10   10    10          10
# 18281              7             7           7      7    7     7           7
# 18282             12            12          12     12   12    12          12
# 18283            756           756         756    756  756   756         756
# 18287             70            70          70     70   70    70          70
#
# ...

# %%
df_new.groupby(by =  ['cust_id', 'country']). count()
# Out:
#                         invoice_num  invoice_date  year_month  month  day  \
# cust_id country
# 12346   United Kingdom            1             1           1      1    1
# 12347   Iceland                 182           182         182    182  182
# 12348   Finland                  31            31          31     31   31
# 12349   Italy                    73            73          73     73   73
# 12350   Norway                   17            17          17     17   17
# ...                             ...           ...         ...    ...  ...
# 18280   United Kingdom           10            10          10     10   10
# 18281   United Kingdom            7             7           7      7    7
# 18282   United Kingdom           12            12          12     12   12
# 18283   United Kingdom          756           756         756    756  756
# 18287   United Kingdom           70            70          70     70   70
#
# ...

# %%
df_new.groupby(by =  ['cust_id', 'country']) ['invoice_num']. count()
# Out:
# cust_id  country
# 12346    United Kingdom      1
# 12347    Iceland           182
# 12348    Finland            31
# 12349    Italy              73
# 12350    Norway             17
#                           ...
# 18280    United Kingdom     10
# 18281    United Kingdom      7
# 18282    United Kingdom     12
# 18283    United Kingdom    756
# 18287    United Kingdom     70
# Name: invoice_num, Length: 4347, dtype: int64

# %%
df_new.groupby(by = ['cust_id', 'country'], as_index = False)['invoice_num'].count()
# Out:
#       cust_id         country  invoice_num
# 0       12346  United Kingdom            1
# 1       12347         Iceland          182
# 2       12348         Finland           31
# 3       12349           Italy           73
# 4       12350          Norway           17
# ...       ...             ...          ...
# 4342    18280  United Kingdom           10
# 4343    18281  United Kingdom            7
# 4344    18282  United Kingdom           12
# 4345    18283  United Kingdom          756
# 4346    18287  United Kingdom           70
#
# [4347 rows x 3 columns]

# %%
df_new.groupby(by = ['cust_id', 'country'], as_index = False)['invoice_num'].count().head()
# Out:
#    cust_id         country  invoice_num
# 0    12346  United Kingdom            1
# 1    12347         Iceland          182
# 2    12348         Finland           31
# 3    12349           Italy           73
# 4    12350          Norway           17

# %% [markdown]
# # **Data Visualization Libraries**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_new.groupby(by = ['cust_id', 'country'], as_index = False)['invoice_num'].count()
# Out:
#       cust_id         country  invoice_num
# 0       12346  United Kingdom            1
# 1       12347         Iceland          182
# 2       12348         Finland           31
# 3       12349           Italy           73
# 4       12350          Norway           17
# ...       ...             ...          ...
# 4342    18280  United Kingdom           10
# 4343    18281  United Kingdom            7
# 4344    18282  United Kingdom           12
# 4345    18283  United Kingdom          756
# 4346    18287  United Kingdom           70
#
# [4347 rows x 3 columns]

# %%
orders = df_new.groupby(by = ['cust_id', 'country'], as_index = False)['invoice_num'].count()                #series as o/p

# %%
orders
# Out:
#       cust_id         country  invoice_num
# 0       12346  United Kingdom            1
# 1       12347         Iceland          182
# 2       12348         Finland           31
# 3       12349           Italy           73
# 4       12350          Norway           17
# ...       ...             ...          ...
# 4342    18280  United Kingdom           10
# 4343    18281  United Kingdom            7
# 4344    18282  United Kingdom           12
# 4345    18283  United Kingdom          756
# 4346    18287  United Kingdom           70
#
# [4347 rows x 3 columns]

# %% [markdown]
# # **Checking Top 5 most numbers of orders**

# %%
orders.sort_values(by = 'invoice_num', ascending=False).head()
# Out:
#       cust_id         country  invoice_num
# 4019    17841  United Kingdom         7847
# 1888    14911            EIRE         5677
# 1298    14096  United Kingdom         5111
# 334     12748  United Kingdom         4596
# 1670    14606  United Kingdom         2700

# %% [markdown]
# # **Visualizing - Number of orders for different Customers**

# %%
# Group by customer ID and country, counting the number of invoices
orders = df_new.groupby(by=['cust_id', 'country'], as_index=False)['invoice_num'].count()

# Create the plot
plt.subplots(figsize=(15, 6))

# Plot the data
plt.plot(orders['cust_id'], orders['invoice_num'], marker='o', linestyle='-')

# Add labels and title
plt.xlabel("Customer ID")
plt.ylabel("Number of Orders")
plt.title("Number of Orders for Different Customers")

# Display the plot
plt.show()

# %% [markdown]
# # **How much money spent by each customers?**

# %%
df_new.groupby(by = ['cust_id', 'country'])['amount_spent'].sum()
# Out:
# cust_id  country
# 12346    United Kingdom    77183.60
# 12347    Iceland            4310.00
# 12348    Finland            1797.24
# 12349    Italy              1757.55
# 12350    Norway              334.40
#                              ...
# 18280    United Kingdom      180.60
# 18281    United Kingdom       80.82
# 18282    United Kingdom      178.05
# 18283    United Kingdom     2094.88
# 18287    United Kingdom     1837.28
# Name: amount_spent, Length: 4347, dtype: float64

# %%
money_spent = df_new.groupby(by = ['cust_id', 'country'])['amount_spent'].sum()

# %% [markdown]
# # **Top FIVE Customers who spend highest money**

# %%
df_new.groupby(by = ['cust_id', 'country'])['amount_spent'].sum().head(5)
# Out:
# cust_id  country
# 12346    United Kingdom    77183.60
# 12347    Iceland            4310.00
# 12348    Finland            1797.24
# 12349    Italy              1757.55
# 12350    Norway              334.40
# Name: amount_spent, dtype: float64

# %%
# money_spent = df_new.groupby(by=['cust_id', 'country'])['amount_spent'].sum()

# %%
# money_spent.sort_values(by='amount_spent', ascending = False).head(10)

#money_spent = df_new.groupby(by=['cust_id', 'country'])['amount_spent'].sum()

# %%
# Convert the Series to a DataFrame to use column-based operations
#money_spent_df = money_spent.reset_index(name='amount_spent')

# %%
# Sort the DataFrame by 'amount_spent'
#money_spent_df.sort_values(by='amount_spent', ascending=False)                #can also use head()
# Out:
#       cust_id         country  amount_spent
# 1698    14646     Netherlands     280206.02
# 4210    18102  United Kingdom     259657.30
# 3737    17450  United Kingdom     194550.79
# 3017    16446  United Kingdom     168472.50
# 1888    14911            EIRE     143825.06

# %% [markdown]
# # **Top TEN customers who spent highest money**

# %%
df_new.groupby(by = ['cust_id', 'country'])['amount_spent'].sum().head(10)
# Out:
# cust_id  country
# 12346    United Kingdom    77183.60
# 12347    Iceland            4310.00
# 12348    Finland            1797.24
# 12349    Italy              1757.55
# 12350    Norway              334.40
# 12352    Norway             2506.04
# 12353    Bahrain              89.00
# 12354    Spain              1079.40
# 12355    Bahrain             459.40
# 12356    Portugal           2811.43
# Name: amount_spent, dtype: float64

# %% [markdown]
# # **Visualizing - Money spent for different Customers**

# %%
money_spent = df_new.groupby(by=['cust_id', 'country'], as_index=False)['amount_spent'].sum()

plt.subplots(figsize=(15,6))

plt.plot(money_spent.cust_id, money_spent.amount_spent)

plt.xlabel('Customers Id')
plt.ylabel('Money Spent (Dollar)')
plt.title('Money spent for different Customers')

plt.show()

# %%
df_new.head()
# Out:
#   invoice_num        invoice_date  year_month  month  day  hour stock_code  \
# 0      536365 2010-12-01 08:26:00      201012     12    3     8     85123A
# 1      536365 2010-12-01 08:26:00      201012     12    3     8      71053
# 2      536365 2010-12-01 08:26:00      201012     12    3     8     84406B
# 3      536365 2010-12-01 08:26:00      201012     12    3     8     84029G
# 4      536365 2010-12-01 08:26:00      201012     12    3     8     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country  day_of_week
# ...

# %% [markdown]
# **Number of order for different months**

# %%
colors = sns.color_palette()

# %% [markdown]
# # **Initial Data**

# %%
df_new.head()
# Out:
#   invoice_num        invoice_date  year_month  month  day  hour stock_code  \
# 0      536365 2010-12-01 08:26:00      201012     12    3     8     85123A
# 1      536365 2010-12-01 08:26:00      201012     12    3     8      71053
# 2      536365 2010-12-01 08:26:00      201012     12    3     8     84406B
# 3      536365 2010-12-01 08:26:00      201012     12    3     8     84029G
# 4      536365 2010-12-01 08:26:00      201012     12    3     8     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country  day_of_week
# ...

# %%
df_new.groupby('invoice_num')

# %%
df_new.groupby('invoice_num')['year_month']

# %%
df_new.groupby('invoice_num')['year_month'].unique()
# Out:
# invoice_num
# 536365    [201012]
# 536366    [201012]
# 536367    [201012]
# 536368    [201012]
# 536369    [201012]
#             ...
# 581583    [201112]
# 581584    [201112]
# 581585    [201112]
# 581586    [201112]
# 581587    [201112]
# Name: year_month, Length: 18536, dtype: object

# %%
df_new.groupby('invoice_num')['year_month'].unique().value_counts()
# Out:
# year_month
# [201111]    2658
# [201110]    1929
# [201109]    1756
# [201105]    1555
# [201012]    1400
# [201106]    1393
# [201107]    1331
# [201103]    1321
# [201108]    1281
# [201104]    1149
# [201102]     998
# [201101]     987
# [201112]     778
# Name: count, dtype: int64

# %%
df_new.groupby('invoice_num')['year_month'].unique().value_counts().sort_index()
# Out:
# year_month
# [201012]    1400
# [201101]     987
# [201102]     998
# [201103]    1321
# [201104]    1149
# [201105]    1555
# [201106]    1393
# [201107]    1331
# [201108]    1281
# [201109]    1756
# [201110]    1929
# [201111]    2658
# [201112]     778
# Name: count, dtype: int64

# %%
#plt.figure(figsize=(10, 6))

# %% [markdown]
# # **How many orders (per day)?**

# %%
df_new.groupby('invoice_num')

# %%
df_new.groupby('invoice_num')['day']

# %%
df_new.groupby('invoice_num')['day'].unique()
# Out:
# invoice_num
# 536365    [3]
# 536366    [3]
# 536367    [3]
# 536368    [3]
# 536369    [3]
#          ...
# 581583    [5]
# 581584    [5]
# 581585    [5]
# 581586    [5]
# 581587    [5]
# Name: day, Length: 18536, dtype: object

# %%
df_new.groupby('invoice_num')['day'].unique().value_counts()
# Out:
# day
# [4]    4033
# [3]    3455
# [2]    3185
# [1]    2863
# [5]    2831
# [7]    2169
# Name: count, dtype: int64

# %%
df_new.groupby('invoice_num')['day'].unique().value_counts().sort_index()
# Out:
# day
# [1]    2863
# [2]    3185
# [3]    3455
# [4]    4033
# [5]    2831
# [7]    2169
# Name: count, dtype: int64

# %%
color = ['blue', 'green', 'red', 'cyan', 'magenta', 'yellow', 'black']

# %%
# Generate the plot
ax = df_new.groupby('invoice_num')['day'].unique().value_counts().sort_index().plot(
    kind='bar', color=color[0], figsize=(15, 6)
)

# Add labels and title
ax.set_xlabel('Months and Year', fontsize=15)
ax.set_ylabel('Numbers of Orders', fontsize=15)
ax.set_title('Number of orders for different Months (1st Dec 2010 - 9th Dec 2010)', fontsize=15)

# Define the month labels, if you want to customize them
t = ('Dec_10', 'Jan_11', 'Feb_11', 'Mar_11', 'Apr_11', 'May_11', 'Jun_11', 'Jul_11', 'Aug_11', 'Sept_11', 'Oct_11', 'Nov_11', 'Dec_11')

# Check the number of actual x-ticks (labels)
xticks = ax.get_xticks()

# If the number of ticks doesn't match the length of 't', use the available labels from your data
if len(xticks) == len(t):
    ax.set_xticklabels(t, rotation='horizontal', fontsize=13)
else:
    # Create labels based on the actual data values
    ax.set_xticklabels([str(label) for label in ax.get_xticklabels()], rotation='horizontal', fontsize=13)

# Display the plot
plt.show()

# %% [markdown]
# # **Day wise sales count/busniess**

# %%
df_new.head()
# Out:
#   invoice_num        invoice_date  year_month  month  day  hour stock_code  \
# 0      536365 2010-12-01 08:26:00      201012     12    3     8     85123A
# 1      536365 2010-12-01 08:26:00      201012     12    3     8      71053
# 2      536365 2010-12-01 08:26:00      201012     12    3     8     84406B
# 3      536365 2010-12-01 08:26:00      201012     12    3     8     84029G
# 4      536365 2010-12-01 08:26:00      201012     12    3     8     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country  day_of_week
# ...

# %%
df_new.groupby('invoice_num')

# %%
df_new.groupby('invoice_num')['day']

# %%
df_new.groupby('invoice_num')['day'].unique()
# Out:
# invoice_num
# 536365    [3]
# 536366    [3]
# 536367    [3]
# 536368    [3]
# 536369    [3]
#          ...
# 581583    [5]
# 581584    [5]
# 581585    [5]
# 581586    [5]
# 581587    [5]
# Name: day, Length: 18536, dtype: object

# %%
df_new.groupby('invoice_num')['day'].unique().value_counts()
# Out:
# day
# [4]    4033
# [3]    3455
# [2]    3185
# [1]    2863
# [5]    2831
# [7]    2169
# Name: count, dtype: int64

# %%
df_new.groupby('invoice_num')['day'].unique().value_counts().sort_index()
# Out:
# day
# [1]    2863
# [2]    3185
# [3]    3455
# [4]    4033
# [5]    2831
# [7]    2169
# Name: count, dtype: int64

# %% [markdown]
# # **Lets visualize day wise sales**

# %%
color = ['blue', 'green', 'red', 'cyan', 'magenta', 'yellow', 'black']

# %%
ax = df_new.groupby('invoice_num')['day'].unique().value_counts().sort_index().plot(kind = 'bar',color=color[0],figsize=(15,6))

ax.set_xlabel('Day', fontsize=15)
ax.set_ylabel('Numbers of Orders',fontsize=15)
ax.set_title('Number of orders for different Days', fontsize=15)
d = ('Mon', 'Tue', 'Wed', 'Thur', 'Fri', 'Sun')
ax.set_xticklabels(d, rotation='horizontal', fontsize=15)
plt.show()

# %% [markdown]
# # **Discover patter for Unit Price**

# %%
df_new.unit_price.describe()
# Out:
# count    397924.000000
# mean          3.116174
# std          22.096788
# min           0.000000
# 25%           1.250000
# 50%           1.950000
# 75%           3.750000
# max        8142.750000
# Name: unit_price, dtype: float64

# %% [markdown]
# # **Min value for product is zero, so there are some free products**

# %%
# check the distribution of unit price
plt.subplots(figsize = (12,6))

sns.boxplot(df_new.unit_price)
plt.show()

# %% [markdown]
# # **Filter only free products(cost=0)**

# %%
df_free = df_new[df_new.unit_price == 0]

# %%
len(df_free)
# Out:
# 40

# %%
df_free.year_month
# Out:
# 9302      201012
# 33576     201012
# 40089     201012
# 47068     201101
# 47070     201101
# 56674     201101
# 86789     201102
# 130188    201103
# 139453    201103
# 145208    201104
# 157042    201104
# 187613    201105
# 198383    201105
# 279324    201107
# 282912    201107
# 285657    201108
# 298054    201108
# 314745    201108
# 314746    201108
# 314747    201108
# 314748    201108
# 358655    201109
# 361825    201109
# 379913    201110
# 395529    201110
# 420404    201110
# 436428    201111
# 436597    201111
# 436961    201111
# 439361    201111
# 446125    201111
# 446793    201111
# 446794    201111
# 454463    201111
# 454464    201111
# 479079    201111
# 479546    201111
# 480649    201111
# 485985    201111
# 502122    201111
# Name: year_month, dtype: int64

# %%
df_free.year_month.value_counts()
# Out:
# year_month
# 201111    14
# 201108     6
# 201012     3
# 201101     3
# 201110     3
# 201103     2
# 201104     2
# 201105     2
# 201107     2
# 201109     2
# 201102     1
# Name: count, dtype: int64

# %%
df_free.year_month.value_counts().sort_index()
# Out:
# year_month
# 201012     3
# 201101     3
# 201102     1
# 201103     2
# 201104     2
# 201105     2
# 201107     2
# 201108     6
# 201109     2
# 201110     3
# 201111    14
# Name: count, dtype: int64

# %%
color = ['blue', 'green', 'red', 'cyan', 'magenta', 'yellow', 'black']

# %%
# Assuming your DataFrame `df_free` has the 'year_month' column properly formatted.
ax = df_free.year_month.value_counts().sort_index().plot(kind='bar', figsize=(12, 6), color='skyblue')

ax.set_xlabel('Month', fontsize=15)
ax.set_ylabel('Frequency', fontsize=15)
ax.set_title('Frequency for different Months (Dec-2010 - Dec-2011)', fontsize=15)

# Define months for x-axis labels
m = ('Dec_10', 'Jan_11', 'Feb_11', 'Mar_11', 'Apr_11', 'May_11', 'Jun_11', 'Jul_11', 'Aug_11', 'Sept_11', 'Oct_11', 'Nov_11', 'Dec_11')

# Get the number of actual months in your dataset
months_in_data = df_free.year_month.value_counts().sort_index().index

# Ensure the number of xticklabels matches the number of months in the data
if len(months_in_data) == len(m):
    ax.set_xticklabels(m, rotation='horizontal', fontsize=13)
else:
    # If there's a mismatch, you can modify the labels or display the months from the dataset
    ax.set_xticklabels(months_in_data, rotation='horizontal', fontsize=13)

# Show the plot
plt.show()

# %% [markdown]
# # **How many orders for each Country?**

# %%
df_new
# Out:
#        invoice_num        invoice_date  year_month  month  day  hour  \
# 0           536365 2010-12-01 08:26:00      201012     12    3     8
# 1           536365 2010-12-01 08:26:00      201012     12    3     8
# 2           536365 2010-12-01 08:26:00      201012     12    3     8
# 3           536365 2010-12-01 08:26:00      201012     12    3     8
# 4           536365 2010-12-01 08:26:00      201012     12    3     8
# ...            ...                 ...         ...    ...  ...   ...
# 541904      581587 2011-12-09 12:50:00      201112     12    5    12
# 541905      581587 2011-12-09 12:50:00      201112     12    5    12
# 541906      581587 2011-12-09 12:50:00      201112     12    5    12
# 541907      581587 2011-12-09 12:50:00      201112     12    5    12
# 541908      581587 2011-12-09 12:50:00      201112     12    5    12
#
#        stock_code                          description  quantity  unit_price  \
# ...

# %%
df_new.groupby('country')

# %%
df_new.groupby('country')['invoice_num']

# %%
df_new.groupby('country')['invoice_num'].count()
# Out:
# country
# Australia                 1185
# Austria                    398
# Bahrain                     17
# Belgium                   2031
# Brazil                      32
# Canada                     151
# Channel Islands            748
# Cyprus                     614
# Czech Republic              25
# Denmark                    380
# EIRE                      7238
# European Community          60
# Finland                    685
# France                    8342
# Germany                   9042
# Greece                     145
# Iceland                    182
# Israel                     248
# Italy                      758
# Japan                      321
# Lebanon                     45
# Lithuania                   35
# Malta                      112
# Netherlands               2363
# Norway                    1072
# Poland                     330
# Portugal                  1462
# RSA                         58
# Saudi Arabia                 9
# Singapore                  222
# ...

# %%
df_new.groupby('country')['invoice_num'].count().sort_values()
# Out:
# country
# Saudi Arabia                 9
# Bahrain                     17
# Czech Republic              25
# Brazil                      32
# Lithuania                   35
# Lebanon                     45
# RSA                         58
# European Community          60
# United Arab Emirates        68
# Malta                      112
# Greece                     145
# Canada                     151
# USA                        179
# Iceland                    182
# Singapore                  222
# Unspecified                244
# Israel                     248
# Japan                      321
# Poland                     330
# Denmark                    380
# Austria                    398
# Sweden                     451
# Cyprus                     614
# Finland                    685
# Channel Islands            748
# Italy                      758
# Norway                    1072
# Australia                 1185
# Portugal                  1462
# Switzerland               1842
# ...

# %% [markdown]
# # **How many orders for each Country?**

# %%
color = ['blue', 'green', 'red', 'cyan', 'magenta', 'yellow', 'black']

# %%
group_country_orders = df_new.groupby('country')['invoice_num'].count().sort_values()

plt.subplots(figsize=(15,8))
group_country_orders.plot(kind = 'barh', fontsize=12, color=color[0])
plt.xlabel('Number of Orders', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Number of orders for different Countries', fontsize=12)

plt.show()

# %%
group_country_orders = df_new.groupby('country')['invoice_num'].count().sort_values()
del group_country_orders['United Kingdom']

plt.subplots(figsize=(15,8))
group_country_orders.plot(kind = 'barh', fontsize=12, color=color[0])
plt.xlabel('Number of Orders', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Number of orders for different Countries', fontsize=12)

plt.show()

# %% [markdown]
# # **How much money spend by each Country?**

# %%
df_new
# Out:
#        invoice_num        invoice_date  year_month  month  day  hour  \
# 0           536365 2010-12-01 08:26:00      201012     12    3     8
# 1           536365 2010-12-01 08:26:00      201012     12    3     8
# 2           536365 2010-12-01 08:26:00      201012     12    3     8
# 3           536365 2010-12-01 08:26:00      201012     12    3     8
# 4           536365 2010-12-01 08:26:00      201012     12    3     8
# ...            ...                 ...         ...    ...  ...   ...
# 541904      581587 2011-12-09 12:50:00      201112     12    5    12
# 541905      581587 2011-12-09 12:50:00      201112     12    5    12
# 541906      581587 2011-12-09 12:50:00      201112     12    5    12
# 541907      581587 2011-12-09 12:50:00      201112     12    5    12
# 541908      581587 2011-12-09 12:50:00      201112     12    5    12
#
#        stock_code                          description  quantity  unit_price  \
# ...

# %%
df_new.groupby('country')

# %%
df_new.groupby('country')['amount_spent']

# %%
df_new.groupby('country')['amount_spent'].sum()
# Out:
# country
# Australia                138521.310
# Austria                   10198.680
# Bahrain                     548.400
# Belgium                   41196.340
# Brazil                     1143.600
# Canada                     3666.380
# Channel Islands           20450.440
# Cyprus                    13590.380
# Czech Republic              826.740
# Denmark                   18955.340
# EIRE                     265545.900
# European Community         1300.250
# Finland                   22546.080
# France                   209024.050
# Germany                  228867.140
# Greece                     4760.520
# Iceland                    4310.000
# Israel                     7221.690
# Italy                     17483.240
# Japan                     37416.370
# Lebanon                    1693.880
# Lithuania                  1661.060
# Malta                      2725.590
# Netherlands              285446.340
# Norway                    36165.440
# Poland                     7334.650
# ...

# %%
df_new.groupby('country')['amount_spent'].sum().sort_values()
# Out:
# country
# Saudi Arabia                145.920
# Bahrain                     548.400
# Czech Republic              826.740
# RSA                        1002.310
# Brazil                     1143.600
# European Community         1300.250
# Lithuania                  1661.060
# Lebanon                    1693.880
# United Arab Emirates       1902.280
# Unspecified                2667.070
# Malta                      2725.590
# USA                        3580.390
# Canada                     3666.380
# Iceland                    4310.000
# Greece                     4760.520
# Israel                     7221.690
# Poland                     7334.650
# Austria                   10198.680
# Cyprus                    13590.380
# Italy                     17483.240
# Denmark                   18955.340
# Channel Islands           20450.440
# Singapore                 21279.290
# Finland                   22546.080
# Portugal                  33439.890
# Norway                    36165.440
# ...

# %% [markdown]
# # **How much money spent by each Country?**

# %%
group_country_amount_spent = df_new.groupby('country')['amount_spent'].sum().sort_values()
#del group_country_orders['United Kingdom']

plt.subplots(figsize=(15,8))
group_country_amount_spent.plot(kind = 'barh', fontsize=12, color=color[0])
plt.xlabel('Money spent (Dollar)', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Number of orders for different Countries', fontsize=12)

plt.show()
